# %%
import pandas as pd
import numpy as np

# %%
data_P = pd.read_csv("countypres_2000-2016.csv")

# %%
data_P.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes   version
# 0    democrat          4942.0       17208  20191203
# 1  republican         11993.0       17208  20191203
# 2       green           160.0       17208  20191203
# 3         NaN           113.0       17208  20191203
# 4    democrat         13997.0       56480  20191203

# %%
data_P.drop(columns ='version', inplace = True)

# %%
data_P.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes
# 0    democrat          4942.0       17208
# 1  republican         11993.0       17208
# 2       green           160.0       17208
# 3         NaN           113.0       17208
# 4    democrat         13997.0       56480

# %%
data2008 = data_P.loc[data_P['year'] == 2008]
data2012 = data_P.loc[data_P['year'] == 2012]
data2016 = data_P.loc[data_P['year'] == 2016]

# %%
Max_votes_16 = data2016.groupby('FIPS')['candidatevotes'].max()               
Max_votes_16 = pd.DataFrame(Max_votes_16)

DataFrame_16 = Max_votes_16.merge(data2016[["year","state", "state_po","county", "candidatevotes", "candidate", "party", "totalvotes", "FIPS", "state_po"]],\
                          on = "FIPS",  how = "left")

df_16 = DataFrame_16[DataFrame_16.candidatevotes_x == DataFrame_16.candidatevotes_y]
df_16.drop(columns ='candidatevotes_x', inplace = True)
df_16 = df_16.rename(columns = {"candidatevotes_y": "candidatevotes"})
df_16
# Out:
# /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          FIPS  year    state state_po      county  candidatevotes  \
# 1      1001.0  2016  Alabama       AL     Autauga         18172.0
# 4      1003.0  2016  Alabama       AL     Baldwin         72883.0
# 7      1005.0  2016  Alabama       AL     Barbour          5454.0
# 10     1007.0  2016  Alabama       AL        Bibb          6738.0
# 13     1009.0  2016  Alabama       AL      Blount         22859.0
# ...       ...   ...      ...      ...         ...             ...
# 9451  56037.0  2016  Wyoming       WY  Sweetwater         12154.0
# 9453  56039.0  2016  Wyoming       WY       Teton          7314.0
# 9457  56041.0  2016  Wyoming       WY       Uinta          6154.0
# 9460  56043.0  2016  Wyoming       WY    Washakie          2911.0
# 9463  56045.0  2016  Wyoming       WY      Weston          3033.0
#
#             candidate       party  totalvotes state_po
# 1        Donald Trump  republican       24973       AL
# 4        Donald Trump  republican       95215       AL
# 7        Donald Trump  republican       10469       AL
# 10       Donald Trump  republican        8819       AL
# 13       Donald Trump  republican       25588       AL
# ...               ...         ...         ...      ...
# 9451     Donald Trump  republican       17130       WY
# 9453  Hillary Clinton    democrat       12627       WY
# 9457     Donald Trump  republican        8470       WY
# 9460     Donald Trump  republican        3814       WY
# 9463     Donald Trump  republican        3526       WY
#
# [3154 rows x 10 columns]

# %%
Max_votes_12 = data2012.groupby('FIPS')['candidatevotes'].max()               
Max_votes_12 = pd.DataFrame(Max_votes_12)

DataFrame_12 = Max_votes_12.merge(data2012[["year","state", "state_po","county", "candidatevotes", "candidate", "party", "totalvotes", "FIPS", "state_po"]],\
                          on = "FIPS",  how = "left")

df_12 = DataFrame_12[DataFrame_12.candidatevotes_x == DataFrame_12.candidatevotes_y]
df_12.drop(columns ='candidatevotes_x', inplace = True)
df_12 = df_12.rename(columns = {"candidatevotes_y": "candidatevotes"})
df_12
# Out:
# /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          FIPS  year    state state_po      county  candidatevotes  \
# 1      1001.0  2012  Alabama       AL     Autauga         17379.0
# 4      1003.0  2012  Alabama       AL     Baldwin         66016.0
# 6      1005.0  2012  Alabama       AL     Barbour          5912.0
# 10     1007.0  2012  Alabama       AL        Bibb          6132.0
# 13     1009.0  2012  Alabama       AL      Blount         20757.0
# ...       ...   ...      ...      ...         ...             ...
# 9451  56037.0  2012  Wyoming       WY  Sweetwater         11428.0
# 9453  56039.0  2012  Wyoming       WY       Teton          6213.0
# 9457  56041.0  2012  Wyoming       WY       Uinta          6615.0
# 9460  56043.0  2012  Wyoming       WY    Washakie          3014.0
# 9463  56045.0  2012  Wyoming       WY      Weston          2821.0
#
#          candidate       party  totalvotes state_po
# 1      Mitt Romney  republican       23932       AL
# 4      Mitt Romney  republican       85338       AL
# 6     Barack Obama    democrat       11509       AL
# 10     Mitt Romney  republican        8420       AL
# 13     Mitt Romney  republican       24006       AL
# ...            ...         ...         ...      ...
# 9451   Mitt Romney  republican       16895       WY
# 9453  Barack Obama    democrat       11464       WY
# 9457   Mitt Romney  republican        8539       WY
# 9460   Mitt Romney  republican        3944       WY
# 9463   Mitt Romney  republican        3359       WY
#
# [3154 rows x 10 columns]

# %%
Max_votes_08 = data2008.groupby('FIPS')['candidatevotes'].max()               
Max_votes_08 = pd.DataFrame(Max_votes_08)

DataFrame_08 = Max_votes_08.merge(data2008[["year","state", "state_po","county", "candidatevotes", "candidate", "party", "totalvotes", "FIPS", "state_po"]],\
                          on = "FIPS",  how = "left")

df_08 = DataFrame_08[DataFrame_08.candidatevotes_x == DataFrame_08.candidatevotes_y]
df_08.drop(columns ='candidatevotes_x', inplace = True)
df_08 = df_08.rename(columns = {"candidatevotes_y": "candidatevotes"})
df_08
# Out:
# /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          FIPS  year    state state_po      county  candidatevotes  \
# 1      1001.0  2008  Alabama       AL     Autauga         17403.0
# 4      1003.0  2008  Alabama       AL     Baldwin         61271.0
# 7      1005.0  2008  Alabama       AL     Barbour          5866.0
# 10     1007.0  2008  Alabama       AL        Bibb          6262.0
# 13     1009.0  2008  Alabama       AL      Blount         20389.0
# ...       ...   ...      ...      ...         ...             ...
# 9451  56037.0  2008  Wyoming       WY  Sweetwater         10360.0
# 9453  56039.0  2008  Wyoming       WY       Teton          7472.0
# 9457  56041.0  2008  Wyoming       WY       Uinta          5763.0
# 9460  56043.0  2008  Wyoming       WY    Washakie          2956.0
# 9463  56045.0  2008  Wyoming       WY      Weston          2618.0
#
#          candidate       party  totalvotes state_po
# 1      John McCain  republican       23641       AL
# 4      John McCain  republican       81413       AL
# 7      John McCain  republican       11630       AL
# 10     John McCain  republican        8644       AL
# 13     John McCain  republican       24267       AL
# ...            ...         ...         ...      ...
# 9451   John McCain  republican       16833       WY
# 9453  Barack Obama    democrat       12359       WY
# 9457   John McCain  republican        8418       WY
# 9460   John McCain  republican        4100       WY
# 9463   John McCain  republican        3414       WY
#
# [3154 rows x 10 columns]

# %%
combined = df_16.append([df_12, df_08])

# %%
combined.head()
# Out:
#       FIPS  year    state state_po   county  candidatevotes     candidate  \
# 1   1001.0  2016  Alabama       AL  Autauga         18172.0  Donald Trump
# 4   1003.0  2016  Alabama       AL  Baldwin         72883.0  Donald Trump
# 7   1005.0  2016  Alabama       AL  Barbour          5454.0  Donald Trump
# 10  1007.0  2016  Alabama       AL     Bibb          6738.0  Donald Trump
# 13  1009.0  2016  Alabama       AL   Blount         22859.0  Donald Trump
#
#          party  totalvotes state_po
# 1   republican       24973       AL
# 4   republican       95215       AL
# 7   republican       10469       AL
# 10  republican        8819       AL
# 13  republican       25588       AL

# %%
combined.loc[combined['party'] == 'democrat']
# Out:
#          FIPS  year      state state_po     county  candidatevotes  \
# 15     1011.0  2016    Alabama       AL    Bullock          3530.0
# 69     1047.0  2016    Alabama       AL     Dallas         12836.0
# 93     1063.0  2016    Alabama       AL     Greene          4013.0
# 96     1065.0  2016    Alabama       AL       Hale          4775.0
# 108    1073.0  2016    Alabama       AL  Jefferson        156873.0
# ...       ...   ...        ...      ...        ...             ...
# 9387  55137.0  2008  Wisconsin       WI   Waushara          5868.0
# 9390  55139.0  2008  Wisconsin       WI  Winnebago         48167.0
# 9393  55141.0  2008  Wisconsin       WI       Wood         21710.0
# 9396  56001.0  2008    Wyoming       WY     Albany          8644.0
# 9453  56039.0  2008    Wyoming       WY      Teton          7472.0
#
#             candidate     party  totalvotes state_po
# 15    Hillary Clinton  democrat        4710       AL
# 69    Hillary Clinton  democrat       18792       AL
# 93    Hillary Clinton  democrat        4880       AL
# 96    Hillary Clinton  democrat        8040       AL
# 108   Hillary Clinton  democrat      304191       AL
# ...               ...       ...         ...      ...
# 9387     Barack Obama  democrat       11849       WI
# 9390     Barack Obama  democrat       87677       WI
# 9393     Barack Obama  democrat       39052       WI
# 9396     Barack Obama  democrat       17201       WY
# 9453     Barack Obama  democrat       12359       WY
#
# [2096 rows x 10 columns]

# %%
combined['party'].unique()
# Out:
# array(['republican', 'democrat'], dtype=object)

# %%
combined_fips = df_16[['FIPS','state']]

# %%
combined_fips = combined_fips.drop_duplicates(subset = 'state')
combined_fips
# Out:
#          FIPS                 state
# 1      1001.0               Alabama
# 202    2001.0                Alaska
# 324    4001.0               Arizona
# 370    5001.0              Arkansas
# 594    6001.0            California
# 768    8001.0              Colorado
# 960    9001.0           Connecticut
# 985   10001.0              Delaware
# 993   11001.0  District of Columbia
# 996   12001.0               Florida
# 1198  13001.0               Georgia
# 1674  15001.0                Hawaii
# 1687  16001.0                 Idaho
# 1819  17001.0              Illinois
# 2125  18001.0               Indiana
# 2401  19001.0                  Iowa
# 2698  20001.0                Kansas
# 3013  21001.0              Kentucky
# 3373  22001.0             Louisiana
# 3565  23001.0                 Maine
# 3613  24001.0              Maryland
# 3684  25001.0         Massachusetts
# 3727  26001.0              Michigan
# 3976  27001.0             Minnesota
# 4236  28001.0           Mississippi
# 4483  29001.0              Missouri
# 4828  30001.0               Montana
# 4996  31001.0              Nebraska
# 5275  32001.0                Nevada
# 5326  33001.0         New Hampshire
# 5355  34001.0            New Jersey
# 5418  35001.0            New Mexico
# 5520  36001.0              New York
# 5707  37001.0        North Carolina
# 6007  38001.0          North Dakota
# 6166  39001.0                  Ohio
# 6430  40001.0              Oklahoma
# 6661  41001.0                Oregon
# 6769  42001.0          Pennsylvania
# 6969  44001.0          Rhode Island
# 6985  45001.0        South Carolina
# 7123  46003.0          South Dakota
# 7321  47001.0             Tennessee
# 7606  48001.0                 Texas
# 8368  49001.0                  Utah
# 8454  50001.0               Vermont
# 8497  51001.0              Virginia
# 8899  53001.0            Washington
# 9016  54001.0         West Virginia
# 9181  55001.0             Wisconsin
# 9397  56001.0               Wyoming

# %%
state_party_08 = pd.DataFrame(df_08.groupby("state")['party'].describe())
state_party_08['year'] = 2008
state_party_12 = pd.DataFrame(df_12.groupby("state")['party'].describe())
state_party_12['year'] = 2012
state_party_16 = pd.DataFrame(df_16.groupby("state")['party'].describe())
state_party_16['year'] = 2016

state_party_all = state_party_12.append([state_party_16, state_party_08])

# %%
result = pd.merge(state_party_all, combined_fips, on = 'state')
result = result.drop_duplicates(subset = ['state', 'year'])

# %%
result
# Out:
#          state count unique         top freq  year     FIPS
# 0      Alabama    67      2  republican   52  2012   1001.0
# 1      Alabama    67      2  republican   54  2016   1001.0
# 2      Alabama    67      2  republican   54  2008   1001.0
# 3       Alaska    40      2  republican   27  2012   2001.0
# 4       Alaska    41      2  republican   27  2016   2001.0
# ..         ...   ...    ...         ...  ...   ...      ...
# 148  Wisconsin    72      2  republican   60  2016  55001.0
# 149  Wisconsin    72      2    democrat   59  2008  55001.0
# 150    Wyoming    23      2  republican   22  2012  56001.0
# 151    Wyoming    23      2  republican   22  2016  56001.0
# 152    Wyoming    23      2  republican   21  2008  56001.0
#
# [153 rows x 7 columns]

# %%
#state_party_all.to_csv("state_pres_combined.csv")

# %%
##df_16.to_csv("state_pres_16.csv")
#df_12.to_csv("state_pres_12.csv")
#df_08.to_csv("state_pres_08.csv")

# %%
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
election = result
X = election[['top', 'year']]
y = election["FIPS"]
#.values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (153, 2) (153,)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras import utils as to_categorical

# %%
data = X.copy()
data_binary_encoded = pd.get_dummies(data, columns=["top"])
data_binary_encoded.head()
# Out:
#    year  top_democrat  top_republican
# 0  2012             0               1
# 1  2016             0               1
# 2  2008             0               1
# 3  2012             0               1
# 4  2016             0               1

# %%
X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.head()
# Out:
#      year  top_democrat  top_republican
# 128  2008             0               1
# 27   2012             0               1
# 64   2016             1               0
# 142  2016             0               1
# 127  2016             0               1

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-186-c1d91a2c503f> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 X_scaler = StandardScaler().fit(X_train)
# ----> 3 y_scaler = StandardScaler().fit(y_train)
#       4
#       5 X_train_scaled = X_scaler.transform(X_train)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     665         # Reset internal state before fitting
#     666         self._reset()
# --> 667         return self.partial_fit(X, y)
#     668
#     669     def partial_fit(self, X, y=None):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     694             Transformer instance.
#     695         """
# --> 696         X = self._validate_data(X, accept_sparse=('csr', 'csc'),
#     697                                 estimator=self, dtype=FLOAT_DTYPES,
#     698                                 force_all_finite='allow-nan')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     618             # If input is 1D raise error
#     619             if array.ndim == 1:
# --> 620                 raise ValueError(
#     621                     "Expected 2D array, got 1D array instead:\narray={}.\n"
#     622                     "Reshape your data either using array.reshape(-1, 1) if "
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[47001. 12001. 25001. 53001. 47001.  2001. 13001. 40001. 34001. 38001.
#   8001. 41001.  5001. 22001. 56001. 41001. 24001. 26001. 37001. 40001.
#  11001.  1001. 18001. 55001. 12001. 17001. 35001. 11001. 10001. 53001.
#  17001. 54001. 45001. 19001. 54001. 44001. 28001. 15001. 35001. 55001.
#  24001. 31001. 32001. 21001.  2001. 36001. 39001. 20001. 15001. 30001.
#  29001. 15001. 44001.  4001. 18001. 27001. 51001. 46003. 31001. 50001.
#  51001. 33001.  4001.  6001. 46003. 51001.  2001.  8001. 16001. 28001.
#  49001.  4001. 44001. 37001.  1001. 25001. 22001. 39001. 20001. 45001.
#  19001. 54001. 24001. 56001. 30001. 23001. 34001. 17001. 47001. 23001.
#  20001. 33001. 10001. 23001. 55001. 48001. 16001. 53001.  1001. 21001.
#  48001. 38001. 37001. 42001. 33001. 28001. 45001. 56001.  9001. 27001.
#  39001.  6001. 34001. 38001.].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)
axes2 = fig1.add_subplot(1, 2, 2)

axes1.set_title("Original Data")
axes2.set_title("Scaled Data")

maxx = X_train["year"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)
axes1.set_ylim(-maxy + 1, maxy + 1)

axes2.set_xlim(-2, 2)
axes2.set_ylim(-2, 2)

def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)
set_axes(axes2)

axes1.scatter(X_train["year"], y_train)
axes2.scatter(X_train_scaled[:,0], y_train_scaled[:])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

predictions = model.predict(X_test_scaled)
MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 0.8738979154579061, R2: -0.12178386756320125

# %%
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
X_train = model.predict(X_train_scaled)
y_train =  (model.predict(X_train_scaled) - y_train_scaled)
X_test = model.predict(X_test_scaled)
y_test = (model.predict(X_test_scaled) - y_test_scaled)

# %%
X_train = pd.DataFrame(np.array(X_train), columns = ['X_train'])
y_train = pd.DataFrame(np.array(y_train), columns = ['y_train'])
X_test = pd.DataFrame(np.array(X_test), columns = ['X_test'])
y_test = pd.DataFrame(np.array(y_test), columns = ['y_test'])

# %%
trained_df = pd.concat([X_train,y_train], axis = 1)

# %%
trained_df.to_csv('Presidential_state_trained.csv')

# %% [markdown]
# # Testing  Learning Model

# %%
voice = result

X = election[['top', 'year']]
y = election["FIPS"]
print(X.shape, y.shape)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

data = X.copy()
data_binary_encoded = pd.get_dummies(data, columns=["top"])
data_binary_encoded.head()

X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# (153, 2) (153,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# %%
# Transform the training and testing data using the X_scaler

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical

# %%
# One-hot encoding
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
'''
# first, create a normal neural network with 2 inputs, 6 hidden nodes, and 2 outputs
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=2))
model.add(Dense(units=2, activation='softmax'))
'''
#create a normal neural network with 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=3))
model.add(Dense(units=56002, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_61 (Dense)             (None, 6)                 24
# _________________________________________________________________
# dense_62 (Dense)             (None, 56002)             392014
# =================================================================
# Total params: 392,038
# Trainable params: 392,038
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# Fit the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 4/4 - 0s - loss: 10.9314 - accuracy: 0.0175
# Epoch 2/100
# 4/4 - 0s - loss: 10.9163 - accuracy: 0.0263
# Epoch 3/100
# 4/4 - 0s - loss: 10.9003 - accuracy: 0.0263
# Epoch 4/100
# 4/4 - 0s - loss: 10.8843 - accuracy: 0.0263
# Epoch 5/100
# 4/4 - 0s - loss: 10.8678 - accuracy: 0.0263
# Epoch 6/100
# 4/4 - 0s - loss: 10.8505 - accuracy: 0.0175
# Epoch 7/100
# 4/4 - 0s - loss: 10.8325 - accuracy: 0.0263
# Epoch 8/100
# 4/4 - 0s - loss: 10.8142 - accuracy: 0.0263
# Epoch 9/100
# 4/4 - 0s - loss: 10.7950 - accuracy: 0.0263
# Epoch 10/100
# 4/4 - 0s - loss: 10.7752 - accuracy: 0.0263
# Epoch 11/100
# 4/4 - 0s - loss: 10.7544 - accuracy: 0.0263
# Epoch 12/100
# 4/4 - 0s - loss: 10.7329 - accuracy: 0.0263
# Epoch 13/100
# 4/4 - 0s - loss: 10.7111 - accuracy: 0.0263
# Epoch 14/100
# 4/4 - 0s - loss: 10.6877 - accuracy: 0.0263
# Epoch 15/100
# 4/4 - 0s - loss: 10.6644 - accuracy: 0.0263
# Epoch 16/100
# 4/4 - 0s - loss: 10.6394 - accuracy: 0.0263
# Epoch 17/100
# 4/4 - 0s - loss: 10.6135 - accuracy: 0.0263
# Epoch 18/100
# 4/4 - 0s - loss: 10.5876 - accuracy: 0.0263
# Epoch 19/100
# 4/4 - 0s - loss: 10.5605 - accuracy: 0.0263
# Epoch 20/100
# 4/4 - 0s - loss: 10.5318 - accuracy: 0.0175
# Epoch 21/100
# 4/4 - 0s - loss: 10.5031 - accuracy: 0.0175
# Epoch 22/100
# 4/4 - 0s - loss: 10.4727 - accuracy: 0.0175
# Epoch 23/100
# 4/4 - 0s - loss: 10.4419 - accuracy: 0.0263
# Epoch 24/100
# 4/4 - 0s - loss: 10.4094 - accuracy: 0.0263
# Epoch 25/100
# 4/4 - 0s - loss: 10.3769 - accuracy: 0.0175
# Epoch 26/100
# 4/4 - 0s - loss: 10.3429 - accuracy: 0.0263
# Epoch 27/100
# 4/4 - 0s - loss: 10.3080 - accuracy: 0.0263
# Epoch 28/100
# 4/4 - 0s - loss: 10.2719 - accuracy: 0.0175
# Epoch 29/100
# 4/4 - 0s - loss: 10.2346 - accuracy: 0.0088
# Epoch 30/100
# 4/4 - 0s - loss: 10.1962 - accuracy: 0.0263
# Epoch 31/100
# 4/4 - 0s - loss: 10.1579 - accuracy: 0.0263
# Epoch 32/100
# 4/4 - 0s - loss: 10.1181 - accuracy: 0.0263
# Epoch 33/100
# 4/4 - 0s - loss: 10.0762 - accuracy: 0.0263
# Epoch 34/100
# 4/4 - 0s - loss: 10.0349 - accuracy: 0.0263
# Epoch 35/100
# 4/4 - 0s - loss: 9.9919 - accuracy: 0.0263
# Epoch 36/100
# 4/4 - 0s - loss: 9.9480 - accuracy: 0.0351
# Epoch 37/100
# 4/4 - 0s - loss: 9.9028 - accuracy: 0.0351
# Epoch 38/100
# 4/4 - 0s - loss: 9.8569 - accuracy: 0.0351
# Epoch 39/100
# 4/4 - 0s - loss: 9.8096 - accuracy: 0.0351
# Epoch 40/100
# 4/4 - 0s - loss: 9.7614 - accuracy: 0.0351
# Epoch 41/100
# 4/4 - 0s - loss: 9.7126 - accuracy: 0.0351
# Epoch 42/100
# 4/4 - 0s - loss: 9.6633 - accuracy: 0.0439
# Epoch 43/100
# 4/4 - 0s - loss: 9.6105 - accuracy: 0.0439
# Epoch 44/100
# 4/4 - 0s - loss: 9.5584 - accuracy: 0.0439
# Epoch 45/100
# 4/4 - 0s - loss: 9.5049 - accuracy: 0.0439
# Epoch 46/100
# 4/4 - 0s - loss: 9.4499 - accuracy: 0.0439
# Epoch 47/100
# 4/4 - 0s - loss: 9.3944 - accuracy: 0.0439
# Epoch 48/100
# 4/4 - 0s - loss: 9.3361 - accuracy: 0.0439
# Epoch 49/100
# 4/4 - 0s - loss: 9.2802 - accuracy: 0.0439
# Epoch 50/100
# 4/4 - 0s - loss: 9.2205 - accuracy: 0.0439
# Epoch 51/100
# 4/4 - 0s - loss: 9.1613 - accuracy: 0.0439
# Epoch 52/100
# 4/4 - 0s - loss: 9.1008 - accuracy: 0.0439
# Epoch 53/100
# 4/4 - 0s - loss: 9.0384 - accuracy: 0.0439
# Epoch 54/100
# 4/4 - 0s - loss: 8.9767 - accuracy: 0.0439
# Epoch 55/100
# 4/4 - 0s - loss: 8.9130 - accuracy: 0.0439
# Epoch 56/100
# 4/4 - 0s - loss: 8.8482 - accuracy: 0.0439
# Epoch 57/100
# 4/4 - 0s - loss: 8.7823 - accuracy: 0.0439
# Epoch 58/100
# 4/4 - 0s - loss: 8.7156 - accuracy: 0.0439
# Epoch 59/100
# 4/4 - 0s - loss: 8.6482 - accuracy: 0.0439
# Epoch 60/100
# 4/4 - 0s - loss: 8.5789 - accuracy: 0.0439
# Epoch 61/100
# 4/4 - 0s - loss: 8.5087 - accuracy: 0.0439
# Epoch 62/100
# 4/4 - 0s - loss: 8.4390 - accuracy: 0.0439
# Epoch 63/100
# 4/4 - 0s - loss: 8.3673 - accuracy: 0.0439
# Epoch 64/100
# 4/4 - 0s - loss: 8.2952 - accuracy: 0.0439
# Epoch 65/100
# 4/4 - 0s - loss: 8.2214 - accuracy: 0.0439
# Epoch 66/100
# 4/4 - 0s - loss: 8.1478 - accuracy: 0.0439
# Epoch 67/100
# 4/4 - 0s - loss: 8.0740 - accuracy: 0.0439
# Epoch 68/100
# 4/4 - 0s - loss: 7.9985 - accuracy: 0.0439
# Epoch 69/100
# 4/4 - 0s - loss: 7.9224 - accuracy: 0.0439
# Epoch 70/100
# 4/4 - 0s - loss: 7.8464 - accuracy: 0.0439
# Epoch 71/100
# 4/4 - 0s - loss: 7.7694 - accuracy: 0.0439
# Epoch 72/100
# 4/4 - 0s - loss: 7.6929 - accuracy: 0.0439
# Epoch 73/100
# 4/4 - 0s - loss: 7.6150 - accuracy: 0.0439
# Epoch 74/100
# 4/4 - 0s - loss: 7.5373 - accuracy: 0.0351
# Epoch 75/100
# 4/4 - 0s - loss: 7.4602 - accuracy: 0.0439
# Epoch 76/100
# 4/4 - 0s - loss: 7.3835 - accuracy: 0.0439
# Epoch 77/100
# 4/4 - 0s - loss: 7.3056 - accuracy: 0.0439
# Epoch 78/100
# 4/4 - 0s - loss: 7.2291 - accuracy: 0.0439
# Epoch 79/100
# 4/4 - 0s - loss: 7.1525 - accuracy: 0.0439
# Epoch 80/100
# 4/4 - 0s - loss: 7.0772 - accuracy: 0.0439
# Epoch 81/100
# 4/4 - 0s - loss: 7.0006 - accuracy: 0.0439
# Epoch 82/100
# 4/4 - 0s - loss: 6.9270 - accuracy: 0.0439
# Epoch 83/100
# 4/4 - 0s - loss: 6.8537 - accuracy: 0.0439
# Epoch 84/100
# 4/4 - 0s - loss: 6.7809 - accuracy: 0.0439
# Epoch 85/100
# 4/4 - 0s - loss: 6.7087 - accuracy: 0.0439
# Epoch 86/100
# 4/4 - 0s - loss: 6.6383 - accuracy: 0.0439
# Epoch 87/100
# 4/4 - 0s - loss: 6.5687 - accuracy: 0.0439
# Epoch 88/100
# 4/4 - 0s - loss: 6.4998 - accuracy: 0.0439
# Epoch 89/100
# 4/4 - 0s - loss: 6.4340 - accuracy: 0.0439
# Epoch 90/100
# 4/4 - 0s - loss: 6.3666 - accuracy: 0.0439
# Epoch 91/100
# 4/4 - 0s - loss: 6.3025 - accuracy: 0.0526
# Epoch 92/100
# 4/4 - 0s - loss: 6.2383 - accuracy: 0.0526
# Epoch 93/100
# 4/4 - 0s - loss: 6.1767 - accuracy: 0.0526
# Epoch 94/100
# 4/4 - 0s - loss: 6.1152 - accuracy: 0.0526
# Epoch 95/100
# 4/4 - 0s - loss: 6.0539 - accuracy: 0.0526
# Epoch 96/100
# 4/4 - 0s - loss: 5.9953 - accuracy: 0.0526
# Epoch 97/100
# 4/4 - 0s - loss: 5.9373 - accuracy: 0.0526
# Epoch 98/100
# 4/4 - 0s - loss: 5.8795 - accuracy: 0.0526
# Epoch 99/100
# 4/4 - 0s - loss: 5.8234 - accuracy: 0.0526
# Epoch 100/100
# 4/4 - 0s - loss: 5.7684 - accuracy: 0.0526

# %% [markdown]
# # deep learning

# %%
deep_model = Sequential()
deep_model.add(Dense(units=50, activation='relu', input_dim=3))
deep_model.add(Dense(units=50, activation='relu'))
deep_model.add(Dense(units=56002, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_63 (Dense)             (None, 50)                200
# _________________________________________________________________
# dense_64 (Dense)             (None, 50)                2550
# _________________________________________________________________
# dense_65 (Dense)             (None, 56002)             2856102
# =================================================================
# Total params: 2,858,852
# Trainable params: 2,858,852
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 4/4 - 0s - loss: 3.3209 - accuracy: 0.0263
# Epoch 2/100
# 4/4 - 0s - loss: 3.2845 - accuracy: 0.0439
# Epoch 3/100
# 4/4 - 0s - loss: 3.2743 - accuracy: 0.0526
# Epoch 4/100
# 4/4 - 0s - loss: 3.2704 - accuracy: 0.0526
# Epoch 5/100
# 4/4 - 0s - loss: 3.2671 - accuracy: 0.0351
# Epoch 6/100
# 4/4 - 0s - loss: 3.2668 - accuracy: 0.0351
# Epoch 7/100
# 4/4 - 0s - loss: 3.2652 - accuracy: 0.0439
# Epoch 8/100
# 4/4 - 0s - loss: 3.2614 - accuracy: 0.0526
# Epoch 9/100
# 4/4 - 0s - loss: 3.2619 - accuracy: 0.0526
# Epoch 10/100
# 4/4 - 0s - loss: 3.2581 - accuracy: 0.0439
# Epoch 11/100
# 4/4 - 0s - loss: 3.2560 - accuracy: 0.0439
# Epoch 12/100
# 4/4 - 0s - loss: 3.2562 - accuracy: 0.0526
# Epoch 13/100
# 4/4 - 0s - loss: 3.2547 - accuracy: 0.0439
# Epoch 14/100
# 4/4 - 0s - loss: 3.2536 - accuracy: 0.0439
# Epoch 15/100
# 4/4 - 0s - loss: 3.2517 - accuracy: 0.0526
# Epoch 16/100
# 4/4 - 0s - loss: 3.2509 - accuracy: 0.0526
# Epoch 17/100
# 4/4 - 0s - loss: 3.2481 - accuracy: 0.0439
# Epoch 18/100
# 4/4 - 0s - loss: 3.2463 - accuracy: 0.0351
# Epoch 19/100
# 4/4 - 0s - loss: 3.2457 - accuracy: 0.0526
# Epoch 20/100
# 4/4 - 0s - loss: 3.2465 - accuracy: 0.0439
# Epoch 21/100
# 4/4 - 0s - loss: 3.2453 - accuracy: 0.0526
# Epoch 22/100
# 4/4 - 0s - loss: 3.2458 - accuracy: 0.0439
# Epoch 23/100
# 4/4 - 0s - loss: 3.2420 - accuracy: 0.0526
# Epoch 24/100
# 4/4 - 0s - loss: 3.2441 - accuracy: 0.0351
# Epoch 25/100
# 4/4 - 0s - loss: 3.2434 - accuracy: 0.0175
# Epoch 26/100
# 4/4 - 0s - loss: 3.2418 - accuracy: 0.0351
# Epoch 27/100
# 4/4 - 0s - loss: 3.2416 - accuracy: 0.0351
# Epoch 28/100
# 4/4 - 0s - loss: 3.2392 - accuracy: 0.0439
# Epoch 29/100
# 4/4 - 0s - loss: 3.2363 - accuracy: 0.0439
# Epoch 30/100
# 4/4 - 0s - loss: 3.2360 - accuracy: 0.0526
# Epoch 31/100
# 4/4 - 0s - loss: 3.2349 - accuracy: 0.0439
# Epoch 32/100
# 4/4 - 0s - loss: 3.2340 - accuracy: 0.0526
# Epoch 33/100
# 4/4 - 0s - loss: 3.2352 - accuracy: 0.0614
# Epoch 34/100
# 4/4 - 0s - loss: 3.2367 - accuracy: 0.0526
# Epoch 35/100
# 4/4 - 0s - loss: 3.2344 - accuracy: 0.0526
# Epoch 36/100
# 4/4 - 0s - loss: 3.2325 - accuracy: 0.0526
# Epoch 37/100
# 4/4 - 0s - loss: 3.2314 - accuracy: 0.0526
# Epoch 38/100
# 4/4 - 0s - loss: 3.2325 - accuracy: 0.0526
# Epoch 39/100
# 4/4 - 0s - loss: 3.2333 - accuracy: 0.0526
# Epoch 40/100
# 4/4 - 0s - loss: 3.2325 - accuracy: 0.0526
# Epoch 41/100
# 4/4 - 0s - loss: 3.2307 - accuracy: 0.0439
# Epoch 42/100
# 4/4 - 0s - loss: 3.2315 - accuracy: 0.0526
# Epoch 43/100
# 4/4 - 0s - loss: 3.2311 - accuracy: 0.0526
# Epoch 44/100
# 4/4 - 0s - loss: 3.2291 - accuracy: 0.0439
# Epoch 45/100
# 4/4 - 0s - loss: 3.2299 - accuracy: 0.0526
# Epoch 46/100
# 4/4 - 0s - loss: 3.2313 - accuracy: 0.0526
# Epoch 47/100
# 4/4 - 0s - loss: 3.2273 - accuracy: 0.0439
# Epoch 48/100
# 4/4 - 0s - loss: 3.2260 - accuracy: 0.0526
# Epoch 49/100
# 4/4 - 0s - loss: 3.2265 - accuracy: 0.0439
# Epoch 50/100
# 4/4 - 0s - loss: 3.2252 - accuracy: 0.0439
# Epoch 51/100
# 4/4 - 0s - loss: 3.2213 - accuracy: 0.0439
# Epoch 52/100
# 4/4 - 0s - loss: 3.2239 - accuracy: 0.0439
# Epoch 53/100
# 4/4 - 0s - loss: 3.2234 - accuracy: 0.0526
# Epoch 54/100
# 4/4 - 0s - loss: 3.2220 - accuracy: 0.0439
# Epoch 55/100
# 4/4 - 0s - loss: 3.2235 - accuracy: 0.0439
# Epoch 56/100
# 4/4 - 0s - loss: 3.2216 - accuracy: 0.0526
# Epoch 57/100
# 4/4 - 0s - loss: 3.2209 - accuracy: 0.0439
# Epoch 58/100
# 4/4 - 0s - loss: 3.2232 - accuracy: 0.0439
# Epoch 59/100
# 4/4 - 0s - loss: 3.2244 - accuracy: 0.0439
# Epoch 60/100
# 4/4 - 0s - loss: 3.2218 - accuracy: 0.0351
# Epoch 61/100
# 4/4 - 0s - loss: 3.2221 - accuracy: 0.0526
# Epoch 62/100
# 4/4 - 0s - loss: 3.2189 - accuracy: 0.0439
# Epoch 63/100
# 4/4 - 0s - loss: 3.2197 - accuracy: 0.0526
# Epoch 64/100
# 4/4 - 0s - loss: 3.2184 - accuracy: 0.0526
# Epoch 65/100
# 4/4 - 0s - loss: 3.2191 - accuracy: 0.0526
# Epoch 66/100
# 4/4 - 0s - loss: 3.2210 - accuracy: 0.0526
# Epoch 67/100
# 4/4 - 0s - loss: 3.2183 - accuracy: 0.0439
# Epoch 68/100
# 4/4 - 0s - loss: 3.2184 - accuracy: 0.0439
# Epoch 69/100
# 4/4 - 0s - loss: 3.2179 - accuracy: 0.0439
# Epoch 70/100
# 4/4 - 0s - loss: 3.2165 - accuracy: 0.0439
# Epoch 71/100
# 4/4 - 0s - loss: 3.2150 - accuracy: 0.0439
# Epoch 72/100
# 4/4 - 0s - loss: 3.2147 - accuracy: 0.0351
# Epoch 73/100
# 4/4 - 0s - loss: 3.2137 - accuracy: 0.0439
# Epoch 74/100
# 4/4 - 0s - loss: 3.2186 - accuracy: 0.0439
# Epoch 75/100
# 4/4 - 0s - loss: 3.2154 - accuracy: 0.0439
# Epoch 76/100
# 4/4 - 0s - loss: 3.2149 - accuracy: 0.0439
# Epoch 77/100
# 4/4 - 0s - loss: 3.2140 - accuracy: 0.0439
# Epoch 78/100
# 4/4 - 0s - loss: 3.2140 - accuracy: 0.0439
# Epoch 79/100
# 4/4 - 0s - loss: 3.2134 - accuracy: 0.0439
# Epoch 80/100
# 4/4 - 0s - loss: 3.2128 - accuracy: 0.0526
# Epoch 81/100
# 4/4 - 0s - loss: 3.2140 - accuracy: 0.0439
# Epoch 82/100
# 4/4 - 0s - loss: 3.2147 - accuracy: 0.0439
# Epoch 83/100
# 4/4 - 0s - loss: 3.2147 - accuracy: 0.0439
# Epoch 84/100
# 4/4 - 0s - loss: 3.2128 - accuracy: 0.0439
# Epoch 85/100
# 4/4 - 0s - loss: 3.2118 - accuracy: 0.0263
# Epoch 86/100
# 4/4 - 0s - loss: 3.2118 - accuracy: 0.0351
# Epoch 87/100
# 4/4 - 0s - loss: 3.2126 - accuracy: 0.0439
# Epoch 88/100
# 4/4 - 0s - loss: 3.2099 - accuracy: 0.0439
# Epoch 89/100
# 4/4 - 0s - loss: 3.2094 - accuracy: 0.0439
# Epoch 90/100
# 4/4 - 0s - loss: 3.2114 - accuracy: 0.0439
# Epoch 91/100
# 4/4 - 0s - loss: 3.2104 - accuracy: 0.0263
# Epoch 92/100
# 4/4 - 0s - loss: 3.2097 - accuracy: 0.0526
# Epoch 93/100
# 4/4 - 0s - loss: 3.2087 - accuracy: 0.0526
# Epoch 94/100
# 4/4 - 0s - loss: 3.2081 - accuracy: 0.0526
# Epoch 95/100
# 4/4 - 0s - loss: 3.2093 - accuracy: 0.0351
# Epoch 96/100
# 4/4 - 0s - loss: 3.2088 - accuracy: 0.0526
# Epoch 97/100
# 4/4 - 0s - loss: 3.2088 - accuracy: 0.0439
# Epoch 98/100
# 4/4 - 0s - loss: 3.2076 - accuracy: 0.0526
# Epoch 99/100
# 4/4 - 0s - loss: 3.2074 - accuracy: 0.0439
# Epoch 100/100
# 4/4 - 0s - loss: 3.2071 - accuracy: 0.0351

# %% [markdown]
# # comparing the models

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-210-bc1fadfd0232> in <module>
# ----> 1 model_loss, model_accuracy = model.evaluate(
#       2     X_test_scaled, y_test_categorical, verbose=2)
#       3 print(
#       4     f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1377             with trace.Trace('TraceContext', graph_type='test', step_num=step):
#    1378               callbacks.on_test_batch_begin(step)
# -> 1379               tmp_logs = test_function(iterator)
#    1380               if data_handler.should_sync:
#    1381                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     812       # In this case we have not created variables on the first call. So we can
#     813       # run the first trace but we should fail if variables are created.
# --> 814       results = self._stateful_fn(*args, **kwds)
#     815       if self._created_variables:
#     816         raise ValueError("Creating variables on a non-first call to a function"
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2826     """Calls a graph function specialized to the inputs."""
#    2827     with self._lock:
# -> 2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
#    2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3208           and self.input_signature is None
#    3209           and call_context_key in self._function_cache.missed):
# -> 3210         return self._define_function_with_shape_relaxation(args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _define_function_with_shape_relaxation(self, args, kwargs)
#    3139           expand_composites=True)
#    3140
# -> 3141     graph_function = self._create_graph_function(
#    3142         args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3143     self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3063     arg_names = base_arg_names + missing_arg_names
#    3064     graph_function = ConcreteFunction(
# -> 3065         func_graph_module.func_graph_from_py_func(
#    3066             self._name,
#    3067             self._python_function,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1224 test_function  *
#         return step_function(self, iterator)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1215 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1208 run_step  **
#         outputs = model.test_step(data)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1176 test_step
#         self.compiled_loss(
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 55002) and (None, 56002) are incompatible

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-208-113d6f0d4daf> in <module>
# ----> 1 model_loss, model_accuracy = deep_model.evaluate(
#       2     X_test_scaled, y_test_categorical, verbose=2)
#       3 print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, max_queue_size, workers, use_multiprocessing, return_dict)
#    1377             with trace.Trace('TraceContext', graph_type='test', step_num=step):
#    1378               callbacks.on_test_batch_begin(step)
# -> 1379               tmp_logs = test_function(iterator)
#    1380               if data_handler.should_sync:
#    1381                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     821       # This is the first call of __call__, so we have to initialize.
#     822       initializers = []
# --> 823       self._initialize(args, kwds, add_initializers_to=initializers)
#     824     finally:
#     825       # At this point we know that the initialization is complete (or less
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _initialize(self, args, kwds, add_initializers_to)
#     694     self._graph_deleter = FunctionDeleter(self._lifted_initializer_graph)
#     695     self._concrete_stateful_fn = (
# --> 696         self._stateful_fn._get_concrete_function_internal_garbage_collected(  # pylint: disable=protected-access
#     697             *args, **kwds))
#     698
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _get_concrete_function_internal_garbage_collected(self, *args, **kwargs)
#    2853       args, kwargs = None, None
#    2854     with self._lock:
# -> 2855       graph_function, _, _ = self._maybe_define_function(args, kwargs)
#    2856     return graph_function
#    2857
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3211
#    3212       self._function_cache.missed.add(call_context_key)
# -> 3213       graph_function = self._create_graph_function(args, kwargs)
#    3214       self._function_cache.primary[cache_key] = graph_function
#    3215       return graph_function, args, kwargs
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3063     arg_names = base_arg_names + missing_arg_names
#    3064     graph_function = ConcreteFunction(
# -> 3065         func_graph_module.func_graph_from_py_func(
#    3066             self._name,
#    3067             self._python_function,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes)
#     984         _, original_func = tf_decorator.unwrap(python_func)
#     985
# --> 986       func_outputs = python_func(*func_args, **func_kwargs)
#     987
#     988       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     598         # __wrapped__ allows AutoGraph to swap in a converted function. We give
#     599         # the function a weak reference to itself to avoid a reference cycle.
# --> 600         return weak_wrapped_fn().__wrapped__(*args, **kwds)
#     601     weak_wrapped_fn = weakref.ref(wrapped_fn)
#     602
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     971           except Exception as e:  # pylint:disable=broad-except
#     972             if hasattr(e, "ag_error_metadata"):
# --> 973               raise e.ag_error_metadata.to_exception(e)
#     974             else:
#     975               raise
#
# ValueError: in user code:
#
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1224 test_function  *
#         return step_function(self, iterator)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1215 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:1211 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2585 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/distribute/distribute_lib.py:2945 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1208 run_step  **
#         outputs = model.test_step(data)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1176 test_step
#         self.compiled_loss(
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/compile_utils.py:204 __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/losses.py:149 __call__
#         losses = ag_call(y_true, y_pred)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/losses.py:253 call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/losses.py:1535 categorical_crossentropy
#         return K.categorical_crossentropy(y_true, y_pred, from_logits=from_logits)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201 wrapper
#         return target(*args, **kwargs)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/backend.py:4687 categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#     /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/framework/tensor_shape.py:1134 assert_is_compatible_with
#         raise ValueError("Shapes %s and %s are incompatible" % (self, other))
#
#     ValueError: Shapes (None, 55002) and (None, 56002) are incompatible
