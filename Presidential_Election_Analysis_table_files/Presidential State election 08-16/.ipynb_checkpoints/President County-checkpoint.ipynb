# %%
import pandas as pd
import numpy as np

# %%
data_P = pd.read_csv("countypres_2000-2016.csv")

# %%
data_P.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes   version
# 0    democrat          4942.0       17208  20191203
# 1  republican         11993.0       17208  20191203
# 2       green           160.0       17208  20191203
# 3         NaN           113.0       17208  20191203
# 4    democrat         13997.0       56480  20191203

# %%
data_P.drop(columns ='version', inplace = True)

# %%
data_P.head()
# Out:
#    year    state state_po   county    FIPS     office       candidate  \
# 0  2000  Alabama       AL  Autauga  1001.0  President         Al Gore
# 1  2000  Alabama       AL  Autauga  1001.0  President  George W. Bush
# 2  2000  Alabama       AL  Autauga  1001.0  President     Ralph Nader
# 3  2000  Alabama       AL  Autauga  1001.0  President           Other
# 4  2000  Alabama       AL  Baldwin  1003.0  President         Al Gore
#
#         party  candidatevotes  totalvotes
# 0    democrat          4942.0       17208
# 1  republican         11993.0       17208
# 2       green           160.0       17208
# 3         NaN           113.0       17208
# 4    democrat         13997.0       56480

# %%
data2008 = data_P.loc[data_P['year'] == 2008]
data2012 = data_P.loc[data_P['year'] == 2012]
data2016 = data_P.loc[data_P['year'] == 2016]

# %%
Max_votes_16 = data2016.groupby('FIPS')['candidatevotes'].max()               
Max_votes_16 = pd.DataFrame(Max_votes_16)

DataFrame_16 = Max_votes_16.merge(data2016[["year","state", "state_po","county", "candidatevotes", "candidate", "party", "totalvotes", "FIPS", "state_po"]],\
                          on = "FIPS",  how = "left")

df_16 = DataFrame_16[DataFrame_16.candidatevotes_x == DataFrame_16.candidatevotes_y]
df_16.drop(columns ='candidatevotes_x', inplace = True)
df_16 = df_16.rename(columns = {"candidatevotes_y": "candidatevotes"})
df_16
# Out:
# /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          FIPS  year    state state_po      county  candidatevotes  \
# 1      1001.0  2016  Alabama       AL     Autauga         18172.0
# 4      1003.0  2016  Alabama       AL     Baldwin         72883.0
# 7      1005.0  2016  Alabama       AL     Barbour          5454.0
# 10     1007.0  2016  Alabama       AL        Bibb          6738.0
# 13     1009.0  2016  Alabama       AL      Blount         22859.0
# ...       ...   ...      ...      ...         ...             ...
# 9451  56037.0  2016  Wyoming       WY  Sweetwater         12154.0
# 9453  56039.0  2016  Wyoming       WY       Teton          7314.0
# 9457  56041.0  2016  Wyoming       WY       Uinta          6154.0
# 9460  56043.0  2016  Wyoming       WY    Washakie          2911.0
# 9463  56045.0  2016  Wyoming       WY      Weston          3033.0
#
#             candidate       party  totalvotes state_po
# 1        Donald Trump  republican       24973       AL
# 4        Donald Trump  republican       95215       AL
# 7        Donald Trump  republican       10469       AL
# 10       Donald Trump  republican        8819       AL
# 13       Donald Trump  republican       25588       AL
# ...               ...         ...         ...      ...
# 9451     Donald Trump  republican       17130       WY
# 9453  Hillary Clinton    democrat       12627       WY
# 9457     Donald Trump  republican        8470       WY
# 9460     Donald Trump  republican        3814       WY
# 9463     Donald Trump  republican        3526       WY
#
# [3154 rows x 10 columns]

# %%
Max_votes_12 = data2012.groupby('FIPS')['candidatevotes'].max()               
Max_votes_12 = pd.DataFrame(Max_votes_12)

DataFrame_12 = Max_votes_12.merge(data2012[["year","state", "state_po","county", "candidatevotes", "candidate", "party", "totalvotes", "FIPS", "state_po"]],\
                          on = "FIPS",  how = "left")

df_12 = DataFrame_12[DataFrame_12.candidatevotes_x == DataFrame_12.candidatevotes_y]
df_12.drop(columns ='candidatevotes_x', inplace = True)
df_12 = df_12.rename(columns = {"candidatevotes_y": "candidatevotes"})
df_12
# Out:
# /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          FIPS  year    state state_po      county  candidatevotes  \
# 1      1001.0  2012  Alabama       AL     Autauga         17379.0
# 4      1003.0  2012  Alabama       AL     Baldwin         66016.0
# 6      1005.0  2012  Alabama       AL     Barbour          5912.0
# 10     1007.0  2012  Alabama       AL        Bibb          6132.0
# 13     1009.0  2012  Alabama       AL      Blount         20757.0
# ...       ...   ...      ...      ...         ...             ...
# 9451  56037.0  2012  Wyoming       WY  Sweetwater         11428.0
# 9453  56039.0  2012  Wyoming       WY       Teton          6213.0
# 9457  56041.0  2012  Wyoming       WY       Uinta          6615.0
# 9460  56043.0  2012  Wyoming       WY    Washakie          3014.0
# 9463  56045.0  2012  Wyoming       WY      Weston          2821.0
#
#          candidate       party  totalvotes state_po
# 1      Mitt Romney  republican       23932       AL
# 4      Mitt Romney  republican       85338       AL
# 6     Barack Obama    democrat       11509       AL
# 10     Mitt Romney  republican        8420       AL
# 13     Mitt Romney  republican       24006       AL
# ...            ...         ...         ...      ...
# 9451   Mitt Romney  republican       16895       WY
# 9453  Barack Obama    democrat       11464       WY
# 9457   Mitt Romney  republican        8539       WY
# 9460   Mitt Romney  republican        3944       WY
# 9463   Mitt Romney  republican        3359       WY
#
# [3154 rows x 10 columns]

# %%
Max_votes_08 = data2008.groupby('FIPS')['candidatevotes'].max()               
Max_votes_08 = pd.DataFrame(Max_votes_08)

DataFrame_08 = Max_votes_08.merge(data2008[["year","state", "state_po","county", "candidatevotes", "candidate", "party", "totalvotes", "FIPS", "state_po"]],\
                          on = "FIPS",  how = "left")

df_08 = DataFrame_08[DataFrame_08.candidatevotes_x == DataFrame_08.candidatevotes_y]
df_08.drop(columns ='candidatevotes_x', inplace = True)
df_08 = df_08.rename(columns = {"candidatevotes_y": "candidatevotes"})
df_08
# Out:
# /Users/mckennamiranda/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#          FIPS  year    state state_po      county  candidatevotes  \
# 1      1001.0  2008  Alabama       AL     Autauga         17403.0
# 4      1003.0  2008  Alabama       AL     Baldwin         61271.0
# 7      1005.0  2008  Alabama       AL     Barbour          5866.0
# 10     1007.0  2008  Alabama       AL        Bibb          6262.0
# 13     1009.0  2008  Alabama       AL      Blount         20389.0
# ...       ...   ...      ...      ...         ...             ...
# 9451  56037.0  2008  Wyoming       WY  Sweetwater         10360.0
# 9453  56039.0  2008  Wyoming       WY       Teton          7472.0
# 9457  56041.0  2008  Wyoming       WY       Uinta          5763.0
# 9460  56043.0  2008  Wyoming       WY    Washakie          2956.0
# 9463  56045.0  2008  Wyoming       WY      Weston          2618.0
#
#          candidate       party  totalvotes state_po
# 1      John McCain  republican       23641       AL
# 4      John McCain  republican       81413       AL
# 7      John McCain  republican       11630       AL
# 10     John McCain  republican        8644       AL
# 13     John McCain  republican       24267       AL
# ...            ...         ...         ...      ...
# 9451   John McCain  republican       16833       WY
# 9453  Barack Obama    democrat       12359       WY
# 9457   John McCain  republican        8418       WY
# 9460   John McCain  republican        4100       WY
# 9463   John McCain  republican        3414       WY
#
# [3154 rows x 10 columns]

# %%
combined = df_16.append([df_12, df_08])

# %%
combined.head()
# Out:
#       FIPS  year    state state_po   county  candidatevotes     candidate  \
# 1   1001.0  2016  Alabama       AL  Autauga         18172.0  Donald Trump
# 4   1003.0  2016  Alabama       AL  Baldwin         72883.0  Donald Trump
# 7   1005.0  2016  Alabama       AL  Barbour          5454.0  Donald Trump
# 10  1007.0  2016  Alabama       AL     Bibb          6738.0  Donald Trump
# 13  1009.0  2016  Alabama       AL   Blount         22859.0  Donald Trump
#
#          party  totalvotes state_po
# 1   republican       24973       AL
# 4   republican       95215       AL
# 7   republican       10469       AL
# 10  republican        8819       AL
# 13  republican       25588       AL

# %%
combined.loc[combined['party'] == 'democrat']
# Out:
#          FIPS  year      state state_po     county  candidatevotes  \
# 15     1011.0  2016    Alabama       AL    Bullock          3530.0
# 69     1047.0  2016    Alabama       AL     Dallas         12836.0
# 93     1063.0  2016    Alabama       AL     Greene          4013.0
# 96     1065.0  2016    Alabama       AL       Hale          4775.0
# 108    1073.0  2016    Alabama       AL  Jefferson        156873.0
# ...       ...   ...        ...      ...        ...             ...
# 9387  55137.0  2008  Wisconsin       WI   Waushara          5868.0
# 9390  55139.0  2008  Wisconsin       WI  Winnebago         48167.0
# 9393  55141.0  2008  Wisconsin       WI       Wood         21710.0
# 9396  56001.0  2008    Wyoming       WY     Albany          8644.0
# 9453  56039.0  2008    Wyoming       WY      Teton          7472.0
#
#             candidate     party  totalvotes state_po
# 15    Hillary Clinton  democrat        4710       AL
# 69    Hillary Clinton  democrat       18792       AL
# 93    Hillary Clinton  democrat        4880       AL
# 96    Hillary Clinton  democrat        8040       AL
# 108   Hillary Clinton  democrat      304191       AL
# ...               ...       ...         ...      ...
# 9387     Barack Obama  democrat       11849       WI
# 9390     Barack Obama  democrat       87677       WI
# 9393     Barack Obama  democrat       39052       WI
# 9396     Barack Obama  democrat       17201       WY
# 9453     Barack Obama  democrat       12359       WY
#
# [2096 rows x 10 columns]

# %%
combined['party'].unique()
# Out:
# array(['republican', 'democrat'], dtype=object)

# %%
#ombined_fips = df_16[['FIPS','state']]

# %%
combined_fips = pd.read_csv("../state_fips.csv")

# %%
'''combined_fips = combined_fips.drop_duplicates(subset = 'state')
combined_fips
'''

combined_fips.drop(columns = ['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
       'Unnamed: 5', 'Unnamed: 6'], inplace = True)

# %%
combined_fips
# Out:
#     state_fips           state
# 0            2          Alaska
# 1            1         Alabama
# 2            5        Arkansas
# 3            4         Arizona
# 4            6      California
# 5            8        Colorado
# 6            9     Connecticut
# 7           10        Delaware
# 8           12         Florida
# 9           13         Georgia
# 10          15          Hawaii
# 11          19            Iowa
# 12          16           Idaho
# 13          17        Illinois
# 14          18         Indiana
# 15          20          Kansas
# 16          21        Kentucky
# 17          22       Louisiana
# 18          25   Massachusetts
# 19          24        Maryland
# 20          23           Maine
# 21          26        Michigan
# 22          27       Minnesota
# 23          29        Missouri
# 24          28     Mississippi
# 25          30         Montana
# 26          37  North Carolina
# 27          38    North Dakota
# 28          31        Nebraska
# 29          33   New Hampshire
# 30          34      New Jersey
# 31          35      New Mexico
# 32          32          Nevada
# 33          36        New York
# 34          39            Ohio
# 35          40        Oklahoma
# 36          41          Oregon
# 37          42    Pennsylvania
# 38          44    Rhode Island
# 39          45  South Carolina
# 40          46    South Dakota
# 41          47       Tennessee
# 42          48           Texas
# 43          49            Utah
# 44          51        Virginia
# 45          50         Vermont
# 46          53      Washington
# 47          55       Wisconsin
# 48          54   West Virginia
# 49          56         Wyoming

# %%
state_party_08 = pd.DataFrame(df_08.groupby("state")['party'].describe())
state_party_08['year'] = 2008
state_party_12 = pd.DataFrame(df_12.groupby("state")['party'].describe())
state_party_12['year'] = 2012
state_party_16 = pd.DataFrame(df_16.groupby("state")['party'].describe())
state_party_16['year'] = 2016

state_party_all = state_party_12.append([state_party_16, state_party_08])

# %%
result = pd.merge(state_party_all, combined_fips, on = 'state')
result = result.drop_duplicates(subset = ['state', 'year'])

# %%
result
# Out:
#          state count unique         top freq  year  state_fips
# 0      Alabama    67      2  republican   52  2012           1
# 1      Alabama    67      2  republican   54  2016           1
# 2      Alabama    67      2  republican   54  2008           1
# 3       Alaska    40      2  republican   27  2012           2
# 4       Alaska    41      2  republican   27  2016           2
# ..         ...   ...    ...         ...  ...   ...         ...
# 145  Wisconsin    72      2  republican   60  2016          55
# 146  Wisconsin    72      2    democrat   59  2008          55
# 147    Wyoming    23      2  republican   22  2012          56
# 148    Wyoming    23      2  republican   22  2016          56
# 149    Wyoming    23      2  republican   21  2008          56
#
# [150 rows x 7 columns]

# %%
#state_party_all.to_csv("state_pres_combined.csv")

# %%
##df_16.to_csv("state_pres_16.csv")
#df_12.to_csv("state_pres_12.csv")
#df_08.to_csv("state_pres_08.csv")

# %%
import matplotlib.pyplot as plt

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %%
election = result
X = election[['top', 'year']]
y = election["state_fips"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# (150, 2) (150, 1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras import utils as to_categorical

# %%
data = X.copy()
data_binary_encoded = pd.get_dummies(data, columns=["top"])
data_binary_encoded.head()
# Out:
#    year  top_democrat  top_republican
# 0  2012             0               1
# 1  2016             0               1
# 2  2008             0               1
# 3  2012             0               1
# 4  2016             0               1

# %%
X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

X_train.head()
# Out:
#      year  top_democrat  top_republican
# 4    2016             0               1
# 32   2008             1               0
# 142  2016             0               1
# 85   2016             0               1
# 86   2008             1               0

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
fig1 = plt.figure(figsize=(12, 6))
axes1 = fig1.add_subplot(1, 2, 1)
axes2 = fig1.add_subplot(1, 2, 2)

axes1.set_title("Original Data")
axes2.set_title("Scaled Data")

maxx = X_train["year"].max()
maxy = y_train.max()
axes1.set_xlim(-maxx + 1, maxx + 1)
axes1.set_ylim(-maxy + 1, maxy + 1)

axes2.set_xlim(-2, 2)
axes2.set_ylim(-2, 2)

def set_axes(ax):
    ax.spines['left'].set_position('center')
    ax.spines['right'].set_color('none')
    ax.spines['bottom'].set_position('center')
    ax.spines['top'].set_color('none')
    ax.xaxis.set_ticks_position('bottom')
    ax.yaxis.set_ticks_position('left')
    
set_axes(axes1)
set_axes(axes2)

axes1.scatter(X_train["year"], y_train)
axes2.scatter(X_train_scaled[:,0], y_train_scaled[:])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
plt.scatter(model.predict(X_train_scaled), model.predict(X_train_scaled) - y_train_scaled, c="blue", label="Training Data")
plt.scatter(model.predict(X_test_scaled), model.predict(X_test_scaled) - y_test_scaled, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y_test_scaled.min(), xmax=y_test_scaled.max())
plt.title("Residual Plot")
plt.show()

# %%
from sklearn.metrics import mean_squared_error

predictions = model.predict(X_test_scaled)
MSE = mean_squared_error(y_test_scaled, predictions)
r2 = model.score(X_test_scaled, y_test_scaled)

print(f"MSE: {MSE}, R2: {r2}")
# Out:
# MSE: 1.0908856026737948, R2: -0.021465832171463584

# %%
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
X_train = model.predict(X_train_scaled)
y_train =  (model.predict(X_train_scaled) - y_train_scaled)
X_test = model.predict(X_test_scaled)
y_test = (model.predict(X_test_scaled) - y_test_scaled)

# %%
X_train = pd.DataFrame(np.array(X_train), columns = ['X_train'])
y_train = pd.DataFrame(np.array(y_train), columns = ['y_train'])
X_test = pd.DataFrame(np.array(X_test), columns = ['X_test'])
y_test = pd.DataFrame(np.array(y_test), columns = ['y_test'])

# %%
trained_df = pd.concat([X_train,y_train], axis = 1)

# %%
#trained_df.to_csv('Presidential_state_trained.csv')

# %% [markdown]
# # Testing  Learning Model

# %%
voice = result

X = election[['top', 'year']]
y = election["state_fips"]
print(X.shape, y.shape)

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical

data = X.copy()
data_binary_encoded = pd.get_dummies(data, columns=["top"])
data_binary_encoded.head()

X = pd.get_dummies(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)
# Out:
# (150, 2) (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y)
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
from sklearn.preprocessing import StandardScaler

# Create a StandardScater model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# %%
# Transform the training and testing data using the X_scaler

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from tensorflow.keras.utils import to_categorical

# %%
# One-hot encoding
y_train_categorical = to_categorical(y_train)
y_test_categorical = to_categorical(y_test)

# %%
'''
# first, create a normal neural network with 2 inputs, 6 hidden nodes, and 2 outputs
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=2))
model.add(Dense(units=2, activation='softmax'))
'''
#create a normal neural network with 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(units=6, activation='relu', input_dim=3))
model.add(Dense(units=57, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_37"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_92 (Dense)             (None, 6)                 24
# _________________________________________________________________
# dense_93 (Dense)             (None, 57)                399
# =================================================================
# Total params: 423
# Trainable params: 423
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#loss='categorical_crossentropy'

# %%
# Fit the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 4/4 - 0s - loss: 0.0885 - accuracy: 0.0268
# Epoch 2/100
# 4/4 - 0s - loss: 0.0884 - accuracy: 0.0268
# Epoch 3/100
# 4/4 - 0s - loss: 0.0884 - accuracy: 0.0268
# Epoch 4/100
# 4/4 - 0s - loss: 0.0883 - accuracy: 0.0268
# Epoch 5/100
# 4/4 - 0s - loss: 0.0882 - accuracy: 0.0268
# Epoch 6/100
# 4/4 - 0s - loss: 0.0882 - accuracy: 0.0268
# Epoch 7/100
# 4/4 - 0s - loss: 0.0881 - accuracy: 0.0268
# Epoch 8/100
# 4/4 - 0s - loss: 0.0880 - accuracy: 0.0268
# Epoch 9/100
# 4/4 - 0s - loss: 0.0880 - accuracy: 0.0268
# Epoch 10/100
# 4/4 - 0s - loss: 0.0879 - accuracy: 0.0357
# Epoch 11/100
# 4/4 - 0s - loss: 0.0879 - accuracy: 0.0357
# Epoch 12/100
# 4/4 - 0s - loss: 0.0878 - accuracy: 0.0357
# Epoch 13/100
# 4/4 - 0s - loss: 0.0877 - accuracy: 0.0357
# Epoch 14/100
# 4/4 - 0s - loss: 0.0877 - accuracy: 0.0357
# Epoch 15/100
# 4/4 - 0s - loss: 0.0876 - accuracy: 0.0268
# Epoch 16/100
# 4/4 - 0s - loss: 0.0876 - accuracy: 0.0268
# Epoch 17/100
# 4/4 - 0s - loss: 0.0875 - accuracy: 0.0268
# Epoch 18/100
# 4/4 - 0s - loss: 0.0874 - accuracy: 0.0268
# Epoch 19/100
# 4/4 - 0s - loss: 0.0874 - accuracy: 0.0268
# Epoch 20/100
# 4/4 - 0s - loss: 0.0873 - accuracy: 0.0268
# Epoch 21/100
# 4/4 - 0s - loss: 0.0872 - accuracy: 0.0357
# Epoch 22/100
# 4/4 - 0s - loss: 0.0872 - accuracy: 0.0357
# Epoch 23/100
# 4/4 - 0s - loss: 0.0871 - accuracy: 0.0357
# Epoch 24/100
# 4/4 - 0s - loss: 0.0870 - accuracy: 0.0357
# Epoch 25/100
# 4/4 - 0s - loss: 0.0870 - accuracy: 0.0357
# Epoch 26/100
# 4/4 - 0s - loss: 0.0869 - accuracy: 0.0357
# Epoch 27/100
# 4/4 - 0s - loss: 0.0868 - accuracy: 0.0357
# Epoch 28/100
# 4/4 - 0s - loss: 0.0868 - accuracy: 0.0357
# Epoch 29/100
# 4/4 - 0s - loss: 0.0867 - accuracy: 0.0357
# Epoch 30/100
# 4/4 - 0s - loss: 0.0866 - accuracy: 0.0357
# Epoch 31/100
# 4/4 - 0s - loss: 0.0865 - accuracy: 0.0357
# Epoch 32/100
# 4/4 - 0s - loss: 0.0865 - accuracy: 0.0357
# Epoch 33/100
# 4/4 - 0s - loss: 0.0864 - accuracy: 0.0357
# Epoch 34/100
# 4/4 - 0s - loss: 0.0863 - accuracy: 0.0446
# Epoch 35/100
# 4/4 - 0s - loss: 0.0862 - accuracy: 0.0446
# Epoch 36/100
# 4/4 - 0s - loss: 0.0861 - accuracy: 0.0446
# Epoch 37/100
# 4/4 - 0s - loss: 0.0861 - accuracy: 0.0446
# Epoch 38/100
# 4/4 - 0s - loss: 0.0860 - accuracy: 0.0446
# Epoch 39/100
# 4/4 - 0s - loss: 0.0859 - accuracy: 0.0446
# Epoch 40/100
# 4/4 - 0s - loss: 0.0858 - accuracy: 0.0446
# Epoch 41/100
# 4/4 - 0s - loss: 0.0857 - accuracy: 0.0446
# Epoch 42/100
# 4/4 - 0s - loss: 0.0856 - accuracy: 0.0446
# Epoch 43/100
# 4/4 - 0s - loss: 0.0855 - accuracy: 0.0446
# Epoch 44/100
# 4/4 - 0s - loss: 0.0854 - accuracy: 0.0446
# Epoch 45/100
# 4/4 - 0s - loss: 0.0853 - accuracy: 0.0536
# Epoch 46/100
# 4/4 - 0s - loss: 0.0852 - accuracy: 0.0536
# Epoch 47/100
# 4/4 - 0s - loss: 0.0851 - accuracy: 0.0536
# Epoch 48/100
# 4/4 - 0s - loss: 0.0850 - accuracy: 0.0536
# Epoch 49/100
# 4/4 - 0s - loss: 0.0849 - accuracy: 0.0536
# Epoch 50/100
# 4/4 - 0s - loss: 0.0848 - accuracy: 0.0536
# Epoch 51/100
# 4/4 - 0s - loss: 0.0847 - accuracy: 0.0536
# Epoch 52/100
# 4/4 - 0s - loss: 0.0846 - accuracy: 0.0536
# Epoch 53/100
# 4/4 - 0s - loss: 0.0845 - accuracy: 0.0536
# Epoch 54/100
# 4/4 - 0s - loss: 0.0844 - accuracy: 0.0536
# Epoch 55/100
# 4/4 - 0s - loss: 0.0843 - accuracy: 0.0536
# Epoch 56/100
# 4/4 - 0s - loss: 0.0842 - accuracy: 0.0536
# Epoch 57/100
# 4/4 - 0s - loss: 0.0841 - accuracy: 0.0536
# Epoch 58/100
# 4/4 - 0s - loss: 0.0839 - accuracy: 0.0536
# Epoch 59/100
# 4/4 - 0s - loss: 0.0838 - accuracy: 0.0536
# Epoch 60/100
# 4/4 - 0s - loss: 0.0837 - accuracy: 0.0536
# Epoch 61/100
# 4/4 - 0s - loss: 0.0836 - accuracy: 0.0536
# Epoch 62/100
# 4/4 - 0s - loss: 0.0835 - accuracy: 0.0536
# Epoch 63/100
# 4/4 - 0s - loss: 0.0834 - accuracy: 0.0536
# Epoch 64/100
# 4/4 - 0s - loss: 0.0832 - accuracy: 0.0536
# Epoch 65/100
# 4/4 - 0s - loss: 0.0831 - accuracy: 0.0536
# Epoch 66/100
# 4/4 - 0s - loss: 0.0830 - accuracy: 0.0536
# Epoch 67/100
# 4/4 - 0s - loss: 0.0829 - accuracy: 0.0536
# Epoch 68/100
# 4/4 - 0s - loss: 0.0828 - accuracy: 0.0536
# Epoch 69/100
# 4/4 - 0s - loss: 0.0826 - accuracy: 0.0536
# Epoch 70/100
# 4/4 - 0s - loss: 0.0825 - accuracy: 0.0536
# Epoch 71/100
# 4/4 - 0s - loss: 0.0824 - accuracy: 0.0536
# Epoch 72/100
# 4/4 - 0s - loss: 0.0823 - accuracy: 0.0536
# Epoch 73/100
# 4/4 - 0s - loss: 0.0822 - accuracy: 0.0536
# Epoch 74/100
# 4/4 - 0s - loss: 0.0820 - accuracy: 0.0536
# Epoch 75/100
# 4/4 - 0s - loss: 0.0819 - accuracy: 0.0536
# Epoch 76/100
# 4/4 - 0s - loss: 0.0818 - accuracy: 0.0536
# Epoch 77/100
# 4/4 - 0s - loss: 0.0817 - accuracy: 0.0536
# Epoch 78/100
# 4/4 - 0s - loss: 0.0816 - accuracy: 0.0536
# Epoch 79/100
# 4/4 - 0s - loss: 0.0815 - accuracy: 0.0625
# Epoch 80/100
# 4/4 - 0s - loss: 0.0814 - accuracy: 0.0536
# Epoch 81/100
# 4/4 - 0s - loss: 0.0813 - accuracy: 0.0536
# Epoch 82/100
# 4/4 - 0s - loss: 0.0812 - accuracy: 0.0536
# Epoch 83/100
# 4/4 - 0s - loss: 0.0810 - accuracy: 0.0536
# Epoch 84/100
# 4/4 - 0s - loss: 0.0809 - accuracy: 0.0536
# Epoch 85/100
# 4/4 - 0s - loss: 0.0808 - accuracy: 0.0536
# Epoch 86/100
# 4/4 - 0s - loss: 0.0807 - accuracy: 0.0536
# Epoch 87/100
# 4/4 - 0s - loss: 0.0806 - accuracy: 0.0536
# Epoch 88/100
# 4/4 - 0s - loss: 0.0805 - accuracy: 0.0536
# Epoch 89/100
# 4/4 - 0s - loss: 0.0804 - accuracy: 0.0536
# Epoch 90/100
# 4/4 - 0s - loss: 0.0803 - accuracy: 0.0536
# Epoch 91/100
# 4/4 - 0s - loss: 0.0802 - accuracy: 0.0536
# Epoch 92/100
# 4/4 - 0s - loss: 0.0801 - accuracy: 0.0536
# Epoch 93/100
# 4/4 - 0s - loss: 0.0800 - accuracy: 0.0536
# Epoch 94/100
# 4/4 - 0s - loss: 0.0800 - accuracy: 0.0536
# Epoch 95/100
# 4/4 - 0s - loss: 0.0799 - accuracy: 0.0536
# Epoch 96/100
# 4/4 - 0s - loss: 0.0798 - accuracy: 0.0536
# Epoch 97/100
# 4/4 - 0s - loss: 0.0797 - accuracy: 0.0536
# Epoch 98/100
# 4/4 - 0s - loss: 0.0796 - accuracy: 0.0536
# Epoch 99/100
# 4/4 - 0s - loss: 0.0795 - accuracy: 0.0536
# Epoch 100/100
# 4/4 - 0s - loss: 0.0794 - accuracy: 0.0536

# %% [markdown]
# # deep learning

# %%
deep_model = Sequential()
deep_model.add(Dense(units=6, activation='relu', input_dim=3))
deep_model.add(Dense(units=6, activation='relu'))
deep_model.add(Dense(units=57, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_35"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_87 (Dense)             (None, 6)                 24
# _________________________________________________________________
# dense_88 (Dense)             (None, 6)                 42
# _________________________________________________________________
# dense_89 (Dense)             (None, 57)                399
# =================================================================
# Total params: 465
# Trainable params: 465
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Epoch 1/100
# 4/4 - 0s - loss: 4.0372 - accuracy: 0.0179
# Epoch 2/100
# 4/4 - 0s - loss: 4.0300 - accuracy: 0.0357
# Epoch 3/100
# 4/4 - 0s - loss: 4.0243 - accuracy: 0.0357
# Epoch 4/100
# 4/4 - 0s - loss: 4.0181 - accuracy: 0.0357
# Epoch 5/100
# 4/4 - 0s - loss: 4.0130 - accuracy: 0.0446
# Epoch 6/100
# 4/4 - 0s - loss: 4.0069 - accuracy: 0.0268
# Epoch 7/100
# 4/4 - 0s - loss: 4.0020 - accuracy: 0.0446
# Epoch 8/100
# 4/4 - 0s - loss: 3.9961 - accuracy: 0.0446
# Epoch 9/100
# 4/4 - 0s - loss: 3.9914 - accuracy: 0.0446
# Epoch 10/100
# 4/4 - 0s - loss: 3.9857 - accuracy: 0.0446
# Epoch 11/100
# 4/4 - 0s - loss: 3.9802 - accuracy: 0.0446
# Epoch 12/100
# 4/4 - 0s - loss: 3.9747 - accuracy: 0.0446
# Epoch 13/100
# 4/4 - 0s - loss: 3.9693 - accuracy: 0.0446
# Epoch 14/100
# 4/4 - 0s - loss: 3.9633 - accuracy: 0.0357
# Epoch 15/100
# 4/4 - 0s - loss: 3.9578 - accuracy: 0.0446
# Epoch 16/100
# 4/4 - 0s - loss: 3.9519 - accuracy: 0.0446
# Epoch 17/100
# 4/4 - 0s - loss: 3.9461 - accuracy: 0.0446
# Epoch 18/100
# 4/4 - 0s - loss: 3.9400 - accuracy: 0.0446
# Epoch 19/100
# 4/4 - 0s - loss: 3.9344 - accuracy: 0.0446
# Epoch 20/100
# 4/4 - 0s - loss: 3.9278 - accuracy: 0.0536
# Epoch 21/100
# 4/4 - 0s - loss: 3.9217 - accuracy: 0.0536
# Epoch 22/100
# 4/4 - 0s - loss: 3.9146 - accuracy: 0.0536
# Epoch 23/100
# 4/4 - 0s - loss: 3.9088 - accuracy: 0.0446
# Epoch 24/100
# 4/4 - 0s - loss: 3.9022 - accuracy: 0.0536
# Epoch 25/100
# 4/4 - 0s - loss: 3.8958 - accuracy: 0.0536
# Epoch 26/100
# 4/4 - 0s - loss: 3.8893 - accuracy: 0.0536
# Epoch 27/100
# 4/4 - 0s - loss: 3.8825 - accuracy: 0.0536
# Epoch 28/100
# 4/4 - 0s - loss: 3.8756 - accuracy: 0.0536
# Epoch 29/100
# 4/4 - 0s - loss: 3.8697 - accuracy: 0.0536
# Epoch 30/100
# 4/4 - 0s - loss: 3.8630 - accuracy: 0.0536
# Epoch 31/100
# 4/4 - 0s - loss: 3.8563 - accuracy: 0.0536
# Epoch 32/100
# 4/4 - 0s - loss: 3.8500 - accuracy: 0.0536
# Epoch 33/100
# 4/4 - 0s - loss: 3.8438 - accuracy: 0.0536
# Epoch 34/100
# 4/4 - 0s - loss: 3.8373 - accuracy: 0.0536
# Epoch 35/100
# 4/4 - 0s - loss: 3.8316 - accuracy: 0.0446
# Epoch 36/100
# 4/4 - 0s - loss: 3.8253 - accuracy: 0.0536
# Epoch 37/100
# 4/4 - 0s - loss: 3.8195 - accuracy: 0.0536
# Epoch 38/100
# 4/4 - 0s - loss: 3.8133 - accuracy: 0.0536
# Epoch 39/100
# 4/4 - 0s - loss: 3.8081 - accuracy: 0.0536
# Epoch 40/100
# 4/4 - 0s - loss: 3.8023 - accuracy: 0.0536
# Epoch 41/100
# 4/4 - 0s - loss: 3.7965 - accuracy: 0.0536
# Epoch 42/100
# 4/4 - 0s - loss: 3.7909 - accuracy: 0.0536
# Epoch 43/100
# 4/4 - 0s - loss: 3.7855 - accuracy: 0.0536
# Epoch 44/100
# 4/4 - 0s - loss: 3.7805 - accuracy: 0.0536
# Epoch 45/100
# 4/4 - 0s - loss: 3.7749 - accuracy: 0.0536
# Epoch 46/100
# 4/4 - 0s - loss: 3.7696 - accuracy: 0.0536
# Epoch 47/100
# 4/4 - 0s - loss: 3.7649 - accuracy: 0.0536
# Epoch 48/100
# 4/4 - 0s - loss: 3.7596 - accuracy: 0.0536
# Epoch 49/100
# 4/4 - 0s - loss: 3.7546 - accuracy: 0.0536
# Epoch 50/100
# 4/4 - 0s - loss: 3.7499 - accuracy: 0.0536
# Epoch 51/100
# 4/4 - 0s - loss: 3.7448 - accuracy: 0.0536
# Epoch 52/100
# 4/4 - 0s - loss: 3.7400 - accuracy: 0.0536
# Epoch 53/100
# 4/4 - 0s - loss: 3.7350 - accuracy: 0.0536
# Epoch 54/100
# 4/4 - 0s - loss: 3.7303 - accuracy: 0.0536
# Epoch 55/100
# 4/4 - 0s - loss: 3.7254 - accuracy: 0.0536
# Epoch 56/100
# 4/4 - 0s - loss: 3.7206 - accuracy: 0.0536
# Epoch 57/100
# 4/4 - 0s - loss: 3.7157 - accuracy: 0.0536
# Epoch 58/100
# 4/4 - 0s - loss: 3.7108 - accuracy: 0.0536
# Epoch 59/100
# 4/4 - 0s - loss: 3.7061 - accuracy: 0.0536
# Epoch 60/100
# 4/4 - 0s - loss: 3.7012 - accuracy: 0.0536
# Epoch 61/100
# 4/4 - 0s - loss: 3.6961 - accuracy: 0.0536
# Epoch 62/100
# 4/4 - 0s - loss: 3.6917 - accuracy: 0.0536
# Epoch 63/100
# 4/4 - 0s - loss: 3.6864 - accuracy: 0.0536
# Epoch 64/100
# 4/4 - 0s - loss: 3.6815 - accuracy: 0.0536
# Epoch 65/100
# 4/4 - 0s - loss: 3.6765 - accuracy: 0.0536
# Epoch 66/100
# 4/4 - 0s - loss: 3.6718 - accuracy: 0.0536
# Epoch 67/100
# 4/4 - 0s - loss: 3.6666 - accuracy: 0.0536
# Epoch 68/100
# 4/4 - 0s - loss: 3.6620 - accuracy: 0.0536
# Epoch 69/100
# 4/4 - 0s - loss: 3.6571 - accuracy: 0.0536
# Epoch 70/100
# 4/4 - 0s - loss: 3.6523 - accuracy: 0.0446
# Epoch 71/100
# 4/4 - 0s - loss: 3.6475 - accuracy: 0.0536
# Epoch 72/100
# 4/4 - 0s - loss: 3.6425 - accuracy: 0.0536
# Epoch 73/100
# 4/4 - 0s - loss: 3.6378 - accuracy: 0.0536
# Epoch 74/100
# 4/4 - 0s - loss: 3.6329 - accuracy: 0.0536
# Epoch 75/100
# 4/4 - 0s - loss: 3.6287 - accuracy: 0.0536
# Epoch 76/100
# 4/4 - 0s - loss: 3.6238 - accuracy: 0.0536
# Epoch 77/100
# 4/4 - 0s - loss: 3.6194 - accuracy: 0.0536
# Epoch 78/100
# 4/4 - 0s - loss: 3.6147 - accuracy: 0.0536
# Epoch 79/100
# 4/4 - 0s - loss: 3.6103 - accuracy: 0.0536
# Epoch 80/100
# 4/4 - 0s - loss: 3.6055 - accuracy: 0.0536
# Epoch 81/100
# 4/4 - 0s - loss: 3.6010 - accuracy: 0.0536
# Epoch 82/100
# 4/4 - 0s - loss: 3.5969 - accuracy: 0.0536
# Epoch 83/100
# 4/4 - 0s - loss: 3.5928 - accuracy: 0.0536
# Epoch 84/100
# 4/4 - 0s - loss: 3.5887 - accuracy: 0.0536
# Epoch 85/100
# 4/4 - 0s - loss: 3.5847 - accuracy: 0.0536
# Epoch 86/100
# 4/4 - 0s - loss: 3.5807 - accuracy: 0.0536
# Epoch 87/100
# 4/4 - 0s - loss: 3.5763 - accuracy: 0.0536
# Epoch 88/100
# 4/4 - 0s - loss: 3.5727 - accuracy: 0.0536
# Epoch 89/100
# 4/4 - 0s - loss: 3.5688 - accuracy: 0.0536
# Epoch 90/100
# 4/4 - 0s - loss: 3.5654 - accuracy: 0.0536
# Epoch 91/100
# 4/4 - 0s - loss: 3.5614 - accuracy: 0.0446
# Epoch 92/100
# 4/4 - 0s - loss: 3.5580 - accuracy: 0.0536
# Epoch 93/100
# 4/4 - 0s - loss: 3.5542 - accuracy: 0.0625
# Epoch 94/100
# 4/4 - 0s - loss: 3.5509 - accuracy: 0.0536
# Epoch 95/100
# 4/4 - 0s - loss: 3.5480 - accuracy: 0.0536
# Epoch 96/100
# 4/4 - 0s - loss: 3.5446 - accuracy: 0.0536
# Epoch 97/100
# 4/4 - 0s - loss: 3.5415 - accuracy: 0.0536
# Epoch 98/100
# 4/4 - 0s - loss: 3.5382 - accuracy: 0.0536
# Epoch 99/100
# 4/4 - 0s - loss: 3.5352 - accuracy: 0.0536
# Epoch 100/100
# 4/4 - 0s - loss: 3.5322 - accuracy: 0.0536

# %% [markdown]
# # comparing the models

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(
    f"Normal Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2/2 - 0s - loss: 0.0905 - accuracy: 0.0789
# Normal Neural Network - Loss: 0.09047435224056244, Accuracy: 0.07894736528396606

# %%
model_loss, model_accuracy = deep_model.evaluate(
    X_test_scaled, y_test_categorical, verbose=2)
print(f"Deep Neural Network - Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 2/2 - 0s - loss: 4.0592 - accuracy: 0.0000e+00
# Deep Neural Network - Loss: 4.059233665466309, Accuracy: 0.0
